# %% [markdown]
# ### Bài 1:
# Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
dai,rong=map(float,input().split())
chuvi=2*(dai+rong)
dientich=dai*rong
print(dientich)
print(chuvi)
# Out:
# 10.0
# 4.0

# %% [markdown]
# ### Bài 2:
# Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r=float(input())
pi=3.14
dientich=pi*r**2
chuvi=2*pi*r
print(dientich)
print(chuvi)

# %% [markdown]
# ### Bài 3:
# Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là độ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn hình.

# %%
import math
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    chuvi=a+b+c
    p=(a+b+c)/2
    s=math.sqrt(p*(p-a)*(p-b)*(p-c))
    if a==b==c:
        print(f"La tam giac deu voi chu vi = {chuvi} va dien tich = {s}")
    elif a==b or a==c or b==c:
        print(f"La tam giac can voi chu vi = {chuvi} va dien tich = {s}")
    elif a**2==b**2+c**2 or b**2==a**2+c**2 or c**2==a**2+b**2:
        print(f"La tam giac vuong voi chu vi = {chuvi} va dien tich = {s}")
    else:
        print(f"La tam giac thuong voi chu vi = {chuvi} va dien tich = {s}")
else:
    print("Khong phai ba canh cua tam giac")

# %% [markdown]
# ### Bài 4:
# Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b=map(float,input().split())
print(-b/a)
# Out:
# 0.5

# %% [markdown]
# ### Bài 5:
# Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c=map(int,input().split())
delta=b**2-4*a*c
if delta>0:
    x1=(-b+math.sqrt(delta))/(2*a)
    x2=(-b-math.sqrt(delta))/(2*a)
    print(f"Phuong trinh co hai nghiem phan biet: x1 = {x1} va x2 = {x2}")
elif delta==0:
    x=-b/(2*a)
    print(f"Phuong trinh co nghiem kep: x = {x}")
else:
    print("Phuong trinh vo nghiem")

# %% [markdown]
# ### Bài 6:
# Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d=map(int,input().split())
l=a
if b>l:
    l=b
elif c>l:
    l=c
elif d>l:
    l=d
print(l)
# Out:
# 213

# %% [markdown]
# ### Bài 7:
# Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d=map(int,input().split())
l=a
if b<l:
    l=b
elif c<l:
    l=c
elif d<l:
    l=d
print(l)

# %% [markdown]
# ### Bài 8: Giải hệ phương trình tuyến tính:
# ax + by = m
# cx + dy = n

# %%
a,b,m,c,d,n=map(int,input().split())
b1=b/a
m1=m/a
d1=d/c
n1=n/c
y=(n1-m1)/(d1-b1)
x=(m-b*y)/a
print(x, y)
# Out:
# -1.0 2.0

# %% [markdown]
# ### Bài 9:
# Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x=int(input())
h=x//3600
m=(x-h*3600)//60
s=x-h*3600-m*60
print(f"{h} gio {m} phut {s} giay")
# Out:
# 34 gio 17 phut 36 giay

# %% [markdown]
# ### Bài 10:
# Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
import math
a,b=map(float,input().split())
r=float(input())
x,y=map(float,input().split())
leght= math.sqrt((x-a)**2+(y-b)**2)
if leght<r:
    print("Diem nam trong duong tron")
elif leght==r:
    print("Diem nam tren duong tron")
else:
    print("Diem nam ngoai duong tron")

# %% [markdown]
# ### Bài 11:
# Tính x^y (Với x, y là số thực).

# %%
x,y=map(float,input().split())
print(x**y)
